# %%
import HEDS
# slm = HEDS.SLM.Init()
print([m for m in dir(HEDS) if 'SHOW' in m or 'FLAG' in m or 'WAIT' in m or 'BACKGROUND' in m])
print([m for m in dir(slm) if 'show' in m.lower() or 'wait' in m.lower() or 'frame' in m.lower()])
# Out:
# []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 # slm = HEDS.SLM.Init()
#       3 print([m for m in dir(HEDS) if 'SHOW' in m or 'FLAG' in m or 'WAIT' in m or 'BACKGROUND' in m])
# ----> 4 print([m for m in dir(slm) if 'show' in m.lower() or 'wait' in m.lower() or 'frame' in m.lower()])
#
# NameError: name 'slm' is not defined

# %%
from photonic_annealing import PhotonicAnnealer
import os
import sys
sdk_install_path = r"C:\Program Files\HOLOEYE Photonics\SLM Display SDK (Python) v4.1.0"
python_api_path = os.path.join(sdk_install_path, "api", "python")

if python_api_path not in sys.path:
    sys.path.append(python_api_path)
    print(f"Added {python_api_path} to Python path.")

try:
    import HEDS
    from hedslib.heds_types import *
except ImportError:
    print(f"FATAL ERROR: Could not import HEDS library from {python_api_path}")
    print("Please verify the 'sdk_install_path' variable in this script.")
    sys.exit(1)
